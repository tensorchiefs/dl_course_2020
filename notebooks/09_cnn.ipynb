# %% [markdown]
# # MNIST digit classification before and after shuffling
#
#
# In this notebook you will use a convolutional neural network (CNN), to train two neural networks on the original and the shuffled MNIST dataset and compare the performances.
#
#
# **Dataset:** You work with the MNIST dataset. We have 60'000 28x28 pixel greyscale images of digits and want to classify them into the right label (0-9).
#
# **Content:**
# * load the original MNIST data and create a randomly shuffled version of the data
# * visualize samples of the orginal and shuffled version of the data
# * use keras to train a CNN with the original and shuffled data and compare the perfomance on new unseen test data
# * check if the local structure of the pixels within the images have an impact on the classification performance when you use a CNN

# %% [markdown]
# #### Imports
#
# In the next two cells, we load all the required libraries and functions. We download the Mnist data, normalize the pixelvalues to be between 0 and 1, and seperate it into a training and validation set.

# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow 2.x selected.

# %%
# load required libraries:
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('default')
from sklearn.metrics import confusion_matrix

from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Dense, Convolution2D, MaxPooling2D, Flatten , Activation, Dropout, BatchNormalization
from tensorflow.keras.utils import to_categorical 
from tensorflow.keras import optimizers
import tensorflow as tf

# %%
from tensorflow.keras.datasets import cifar10
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# separate x_train in X_train and X_val, same for y_train
X_train=x_train[0:10000] / 255 #divide by 255 so that they are in range 0 to 1
Y_train=to_categorical(y_train[0:10000],10) # one-hot encoding

X_val=x_train[20000:30000] / 255
Y_val=to_categorical(y_train[20000:30000],10)

X_test=x_test / 255
Y_test=to_categorical(y_test,10)

del x_train, y_train, x_test, y_test


print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
# Out:
# (10000, 32, 32, 3)
# (10000, 32, 32, 3)
# (10000, 32, 32, 3)

# %% [markdown]
# Let's visualize the first 4 mnist images before shuffling the pixels randomly around. It is very easy to recognise the true label of the digits.

# %%
# visualize the 4 first mnist images before shuffling the pixels
plt.figure(figsize=(12,12))
for i in range(0,4):
    plt.subplot(1,4,(i+1))
    plt.imshow((X_train[i,:,:,0]),cmap="gray")
    plt.title('true label: '+np.str(np.argmax(Y_train,axis=1)[i]))
    #plt.axis('off')

# %%
plt.hist(np.argmax(Y_train,axis=1),bins=10)
# Out:
# (array([1005.,  974., 1032., 1016.,  999.,  937., 1030., 1001., 1025.,
#          981.]),
#  array([0. , 0.9, 1.8, 2.7, 3.6, 4.5, 5.4, 6.3, 7.2, 8.1, 9. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(np.argmax(Y_val,axis=1),bins=10)
# Out:
# (array([ 994., 1042.,  965.,  997.,  990., 1029.,  978., 1015.,  961.,
#         1029.]),
#  array([0. , 0.9, 1.8, 2.7, 3.6, 4.5, 5.4, 6.3, 7.2, 8.1, 9. ]),
#  <a list of 10 Patch objects>)

# %%
base_model = tf.keras.applications.vgg16.VGG16(weights='imagenet', include_top=False,input_shape=(32,32,3),pooling="avg")
base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 32, 32, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 32, 32, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 16, 16, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 16, 16, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 16, 16, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 8, 8, 128)         0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 8, 8, 256)         295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 4, 4, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 4, 4, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 1, 1, 512)         0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 512)               0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
X_train_vgg_features=base_model.predict(X_train)
X_val_vgg_features=base_model.predict(X_val)
X_test_vgg_features=base_model.predict(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_estimators=100,random_state=22)
clf.fit(X_train_vgg_features, np.argmax(Y_train,axis=1))
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=22, verbose=0,
#                        warm_start=False)

# %%
pred=clf.predict(X_test_vgg_features)
acc=np.average(pred==np.argmax(Y_test,axis=1))
acc
# Out:
# 0.4907

# %%
base_model = tf.keras.applications.vgg16.VGG16(weights='imagenet', include_top=False,input_shape=(32,32,3))
x = base_model.output
x = Flatten()(x)
x = Dropout(0.3)(x)
x = Dense(400, activation='relu')(x)
x = Dropout(0.3)(x)
x = Dense(200, activation='relu')(x)
x = Dropout(0.3)(x)
predictions = Dense(10, activation='softmax')(x)
model = Model(inputs=base_model.input, outputs=predictions)

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 32, 32, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 32, 32, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 16, 16, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 16, 16, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 16, 16, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 8, 8, 128)         0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 8, 8, 256)         295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 4, 4, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 4, 4, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 512)               0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_39 (Dense)             (None, 400)               205200
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 400)               0
# _________________________________________________________________
# dense_40 (Dense)             (None, 200)               80200
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_41 (Dense)             (None, 10)                2010
# =================================================================
# Total params: 15,002,098
# Trainable params: 15,002,098
# Non-trainable params: 0
# _________________________________________________________________

# %%
for layer in base_model.layers:
    layer.trainable = False
model.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
for i, layer in enumerate(model.layers):
   print(i, layer.name,layer.trainable)
# Out:
# 0 input_4 False
# 1 block1_conv1 False
# 2 block1_conv2 False
# 3 block1_pool False
# 4 block2_conv1 False
# 5 block2_conv2 False
# 6 block2_pool False
# 7 block3_conv1 False
# 8 block3_conv2 False
# 9 block3_conv3 False
# 10 block3_pool False
# 11 block4_conv1 False
# 12 block4_conv2 False
# 13 block4_conv3 False
# 14 block4_pool False
# 15 block5_conv1 False
# 16 block5_conv2 False
# 17 block5_conv3 False
# 18 block5_pool False
# 19 flatten_10 True
# 20 dropout_6 True
# 21 dense_39 True
# 22 dropout_7 True
# 23 dense_40 True
# 24 dropout_8 True
# 25 dense_41 True

# %%
history=model.fit(X_train, Y_train, 
                  batch_size=64, 
                  epochs=40,
                  verbose=1,
                  shuffle=True,
                  validation_data=(X_val, Y_val))
# Out:
# Train on 10000 samples, validate on 10000 samples
# Epoch 1
# %%
# plot the development of the accuracy and loss during training
plt.figure(figsize=(12,4))
plt.subplot(1,2,(1))
plt.plot(history.history['accuracy'],linestyle='-.')
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='lower right')
plt.subplot(1,2,(2))
plt.plot(history.history['loss'],linestyle='-.')
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper right')

# %%
acc=np.average(np.argmax(model.predict(X_test),axis=1)==np.argmax(Y_test,axis=1))
acc
# Out:
# 0.5553

# %%
model  =  Sequential()

model.add(Convolution2D(16,(3,3),activation="relu",padding="same",input_shape=(32,32,3)))
model.add(Convolution2D(16,(3,3),activation="relu",padding="same"))
model.add(MaxPooling2D((2,2)))

model.add(Convolution2D(64,(3,3),activation="relu",padding="same"))
model.add(Convolution2D(64,(3,3),activation="relu",padding="same"))
model.add(MaxPooling2D((4,4)))



model.add(Flatten())
model.add(Dense(500))
model.add(Activation('relu'))
model.add(Dense(300))
model.add(Activation('relu'))
model.add(Dense(100))
model.add(Activation('relu'))

model.add(Dense(10))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_54 (Conv2D)           (None, 32, 32, 16)        448
# _________________________________________________________________
# conv2d_55 (Conv2D)           (None, 32, 32, 16)        2320
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_56 (Conv2D)           (None, 16, 16, 64)        9280
# _________________________________________________________________
# conv2d_57 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_14 (Flatten)         (None, 1024)              0
# _________________________________________________________________
# dense_54 (Dense)             (None, 500)               512500
# _________________________________________________________________
# activation_48 (Activation)   (None, 500)               0
# _________________________________________________________________
# dense_55 (Dense)             (None, 300)               150300
# _________________________________________________________________
# activation_49 (Activation)   (None, 300)               0
# _________________________________________________________________
# dense_56 (Dense)             (None, 100)               30100
# _________________________________________________________________
# activation_50 (Activation)   (None, 100)               0
# _________________________________________________________________
# dense_57 (Dense)             (None, 10)                1010
# _________________________________________________________________
# activation_51 (Activation)   (None, 10)                0
# =================================================================
# Total params: 742,886
# Trainable params: 742,886
# Non-trainable params: 0
# _________________________________________________________________

# %%
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.15,
    height_shift_range=0.15,
    shear_range=0.15,
    zoom_range=0.15,
fill_mode="constant",
cval=1,horizontal_flip=True)

# %%
i=22
data_aug=datagen.flow(x=X_train[i:(i+1)], y=Y_train[i:(i+1)], batch_size=1)
plt.imshow(X_train[i])
plt.show()
plt.figure(figsize=(15,15))
for i in range (0,25):
  plt.subplot(5,5,i+1)
  x_aug,y_aug=next(data_aug)
  plt.imshow(x_aug[0,:,:,:])

# %%
history = model.fit_generator(datagen.flow(X_train, Y_train, batch_size=32), steps_per_epoch=len(X_train)/32, epochs=50, validation_data=(X_val, Y_val),verbose=1)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 312.5 steps, validate on 10000 samples
# Epoch 1/50
# 313/312 [==============================] - 7s 22ms/step - loss: 2.0645 - accuracy: 0.2063 - val_loss: 1.8369 - val_accuracy: 0.3133
# Epoch 2/50
# 313/312 [==============================] - 6s 21ms/step - loss: 1.8072 - accuracy: 0.3131 - val_loss: 1.6759 - val_accuracy: 0.3706
# Epoch 3/50
# 313/312 [==============================] - 6s 20ms/step - loss: 1.6739 - accuracy: 0.3765 - val_loss: 1.7510 - val_accuracy: 0.3845
# Epoch 4/50
# 313/312 [==============================] - 6s 20ms/step - loss: 1.6163 - accuracy: 0.4043 - val_loss: 1.6130 - val_accuracy: 0.4148
# Epoch 5/50
# 313/312 [==============================] - 6s 20ms/step - loss: 1.5464 - accuracy: 0.4236 - val_loss: 1.5521 - val_accuracy: 0.4404
# Epoch 6/50
# 313/312 [==============================] - 6s 20ms/step - loss: 1.4884 - accuracy: 0.4467 - val_loss: 1.3846 - val_accuracy: 0.4896
# Epoch 7/50
# 313/312 [==============================] - 6s 20ms/step - loss: 1.4358 - accuracy: 0.4724 - val_loss: 1.3249 - val_accuracy: 0.5139
# Epoch 8/50
# 313/312 [==============================] - 6s 20ms/step - loss: 1.3779 - accuracy: 0.4953 - val_loss: 1.4040 - val_accuracy: 0.4853
# Epoch 9/50
# 313/312 [==============================] - 7s 21ms/step - loss: 1.3332 - accuracy: 0.5112 - val_loss: 1.2056 - val_accuracy: 0.5576
# Epoch 10/50
# 313/312 [==============================] - 6s 20ms/step - loss: 1.2949 - accuracy: 0.5306 - val_loss: 1.2177 - val_accuracy: 0.5638
# Epoch 11/50
# 313/312 [==============================] - 7s 21ms/step - loss: 1.2463 - accuracy: 0.5477 - val_loss: 1.1322 - val_accuracy: 0.5918
# Epoch 12/50
# 313/312 [==============================] - 6s 20ms/step - loss: 1
50
# 313/312 [==============================] - 6s 20ms/step - loss: 0.7554 - accuracy: 0.7301 - val_loss: 0.9417 - val_accuracy: 0.6892
# Epoch 40/50
# 313/312 [==============================] - 6s 20ms/step - loss: 0.7525 - accuracy: 0.7352 - val_loss: 0.8929 - val_accuracy: 0.7075
# Epoch 41/50
# 313/312 [==============================] - 6s 19ms/step - loss: 0.7490 - accuracy: 0.7342 - val_loss: 0.9220 - val_accuracy: 0.6969
# Epoch 42/50
# 313/312 [==============================] - 6s 20ms/step - loss: 0.7328 - accuracy: 0.7390 - val_loss: 0.9880 - val_accuracy: 0.6883
# Epoch 43/50
# 313/312 [==============================] - 6s 20ms/step - loss: 0.7343 - accuracy: 0.7405 - val_loss: 0.9080 - val_accuracy: 0.6937
# Epoch 44/50
# 313/312 [==============================] - 6s 20ms/step - loss: 0.7233 - accuracy: 0.7411 - val_loss: 0.8713 - val_accuracy: 0.7200
# Epoch 45/50
# 313/312 [==============================] - 6s 20ms/step - loss: 0.7150 - accuracy: 0.7455 - val_loss: 1.0438 - val_accuracy: 0.6766
# Epoch 46/50
# 313/312 [==============================] - 6s 20ms/step - loss: 0.7263 - accuracy: 0.7385 - val_loss: 0.8912 - val_accuracy: 0.7074
# Epoch 47/50
# 313/312 [==============================] - 6s 20ms/step - loss: 0.6961 - accuracy: 0.7540 - val_loss: 0.8963 - val_accuracy: 0.7072
# Epoch 48/50
# 313/312 [==============================] - 6s 20ms/step - loss: 0.6984 - accuracy: 0.7506 - val_loss: 0.8855 - val_accuracy: 0.7076
# Epoch 49/50
# 313/312 [==============================] - 6s 20ms/step - loss: 0.6703 - accuracy: 0.7610 - val_loss: 0.9399 - val_accuracy: 0.7010
# Epoch 50/50
# 313/312 [==============================] - 6s 20ms/step - loss: 0.6746 - accuracy: 0.7579 - val_loss: 0.9802 - val_accuracy: 0.6965

# %%
# plot the development of the accuracy and loss during training
plt.figure(figsize=(12,4))
plt.subplot(1,2,(1))
plt.plot(history.history['accuracy'],linestyle='-.')
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='lower right')
plt.subplot(1,2,(2))
plt.plot(history.history['loss'],linestyle='-.')
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper right')

# %%
acc=np.average(np.argmax(model.predict(X_test),axis=1)==np.argmax(Y_test,axis=1))
acc
# Out:
# 0.6863

# %%
model  =  Sequential()

model.add(Convolution2D(16,(3,3),activation="relu",padding="same",input_shape=(32,32,3)))
model.add(Convolution2D(16,(3,3),activation="relu",padding="same"))
model.add(MaxPooling2D((2,2)))

model.add(Convolution2D(64,(3,3),activation="relu",padding="same"))
model.add(Convolution2D(64,(3,3),activation="relu",padding="same"))
model.add(MaxPooling2D((4,4)))



model.add(Flatten())

model.add(Dense(500))
model.add(Dropout(0.3))
model.add(Activation('relu'))
model.add(Dense(300))
model.add(Dropout(0.3))
model.add(Activation('relu'))
model.add(Dense(100))
model.add(Dropout(0.3))
model.add(Activation('relu'))
model.add(Dense(10))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_46 (Conv2D)           (None, 32, 32, 16)        448
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 32, 32, 16)        2320
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_48 (Conv2D)           (None, 16, 16, 64)        9280
# _________________________________________________________________
# conv2d_49 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 1024)              0
# _________________________________________________________________
# dense_46 (Dense)             (None, 500)               512500
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 500)               0
# _________________________________________________________________
# activation_40 (Activation)   (None, 500)               0
# _________________________________________________________________
# dense_47 (Dense)             (None, 300)               150300
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 300)               0
# _________________________________________________________________
# activation_41 (Activation)   (None, 300)               0
# _________________________________________________________________
# dense_48 (Dense)             (None, 100)               30100
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 100)               0
# _________________________________________________________________
# activation_42 (Activation)   (None, 100)               0
# _________________________________________________________________
# dense_49 (Dense)             (None, 10)                1010
# _________________________________________________________________
# activation_43 (Activation)   (None, 10)                0
# =================================================================
# Total params: 742,886
# Trainable params: 742,886
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, Y_train, batch_size=32, epochs=20, validation_data=(X_val, Y_val),verbose=1)
# Out:
# Train on 10000 samples, validate on 10000 samples
# Epoch 1/20
# 10000/10000 [==============================] - 3s 307us/sample - loss: 2.0556 - accuracy: 0.2151 - val_loss: 1.7222 - val_accuracy: 0.3631
# Epoch 2/20
# 10000/10000 [==============================] - 2s 236us/sample - loss: 1.6370 - accuracy: 0.3897 - val_loss: 1.5124 - val_accuracy: 0.4237
# Epoch 3/20
# 10000/10000 [==============================] - 2s 239us/sample - loss: 1.4546 - accuracy: 0.4613 - val_loss: 1.3328 - val_accuracy: 0.5083
# %%
# plot the development of the accuracy and loss during training
plt.figure(figsize=(12,4))
plt.subplot(1,2,(1))
plt.plot(history.history['accuracy'],linestyle='-.')
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='lower right')
plt.subplot(1,2,(2))
plt.plot(history.history['loss'],linestyle='-.')
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper right')

# %%
acc=np.average(np.argmax(model.predict(X_test),axis=1)==np.argmax(Y_test,axis=1))
acc
# Out:
# 0.6345

# %% [markdown]
# In the next cell we shuffle the pixel of each image randomly around. Note that we shuffle every image in same manner!

# %% [markdown]
# # CNN as classification model for MNIST data
#
# Now, we train a CNN to classify the MNIST data. We use the same netwok architecture and train first with the original data and then with the shuffled data.
# * Use a CNN with 2 convolution blocks and 2 fully connected layers as classification model
# * train it once on the original train data and check the performance on the original test data
# * train it once on the shuffeled train data and check the performance on the accordingly shuffled test data

# %% [markdown]
# ### Train the CNN on the original data

# %%
# check the shape of the orginal data
# we need matrices as input
X_train.shape,Y_train.shape,X_val.shape,Y_val.shape
# Out:
# ((5000, 32, 32, 3), (5000, 10), (10000, 32, 32, 3), (10000, 10))

# %% [markdown]
# In the next cell we define the hyperparameters and architecture of the CNN. We use:
# >the relu activation function
# >batchsize of 128
# >kernelsize of 3x3
# >poolingsize of 2x2
# >our inputs are the greyscaled MNIST images, so the shape is 28x28x1
# > we use 2 convolutional blocks with 8 filters and then a maxpooling layer followed by again 2 convolutional blocks with 16 filters and then a maxpooling
# > then we flatten the output and use a fully connected layer with 40 nodes and the output has 10 nodes with the softmax activation.

# %%
# here we define hyperparameter of the CNN
batch_size = 128
nb_classes = 10
img_rows, img_cols = 32, 32
kernel_size = (3, 3)
input_shape = (img_rows, img_cols, 3)
pool_size = (2, 2)

# %%
# define CNN with 2 convolution blocks and 2 fully connected layers
model = Sequential()

model.add(Convolution2D(8,kernel_size,padding='same',input_shape=input_shape))
model.add(Activation('relu'))
model.add(Convolution2D(8, kernel_size,padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=pool_size))

model.add(Convolution2D(16, kernel_size,padding='same'))
model.add(Activation('relu'))
model.add(Convolution2D(16,kernel_size,padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=pool_size))


model.add(Flatten())
model.add(Dense(300))
model.add(Activation('relu'))
model.add(Dense(100))
model.add(Activation('relu'))
model.add(Dense(nb_classes))
model.add(Activation('softmax'))

# compile model and intitialize weights
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
# summarize model along with number of model weights
model.summary()
# Out:
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_81 (Conv2D)           (None, 32, 32, 8)         224
# _________________________________________________________________
# activation_129 (Activation)  (None, 32, 32, 8)         0
# _________________________________________________________________
# conv2d_82 (Conv2D)           (None, 32, 32, 8)         584
# _________________________________________________________________
# activation_130 (Activation)  (None, 32, 32, 8)         0
# _________________________________________________________________
# max_pooling2d_40 (MaxPooling (None, 16, 16, 8)         0
# _________________________________________________________________
# conv2d_83 (Conv2D)           (None, 16, 16, 16)        1168
# _________________________________________________________________
# activation_131 (Activation)  (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_84 (Conv2D)           (None, 16, 16, 16)        2320
# _________________________________________________________________
# activation_132 (Activation)  (None, 16, 16, 16)        0
# _________________________________________________________________
# max_pooling2d_41 (MaxPooling (None, 8, 8, 16)          0
# _________________________________________________________________
# flatten_20 (Flatten)         (None, 1024)              0
# _________________________________________________________________
# dense_49 (Dense)             (None, 300)               307500
# _________________________________________________________________
# activation_133 (Activation)  (None, 300)               0
# _________________________________________________________________
# dense_50 (Dense)             (None, 100)               30100
# _________________________________________________________________
# activation_134 (Activation)  (None, 100)               0
# _________________________________________________________________
# dense_51 (Dense)             (None, 10)                1010
# _________________________________________________________________
# activation_135 (Activation)  (None, 10)                0
# =================================================================
# Total params: 342,906
# Trainable params: 342,906
# Non-trainable params: 0
# _________________________________________________________________

# %%
# train the model
history=model.fit(X_train, Y_train, 
                  batch_size=64, 
                  epochs=30,
                  verbose=1, 
                  validation_data=(X_val, Y_val)
                 )
# Out:
# Train on 5000 samples, validate on 10000 samples
# Epoch 1/30
# 5000/5000 [==============================] - 2s 365us/sample - loss: 2.0740 - accuracy: 0.2394 - val_loss: 1.8727 - val_accuracy: 0.3070
# Epoch 2/30
# 5000/5000 [==============================] - 1s 219us/sample - loss: 1.7354 - accuracy: 0.3614 - val_loss: 1.7059 - val_accuracy: 0.3780
# Epoch 3/30
# 5000/5000 [==============================] - 1s 211us/sample - loss: 1.5829 - accuracy: 0.4206 - val_loss: 1.5613 - val_accuracy: 0.4301
# Epoch 4/30
# 5000/5000 [==============================] - 1s 215us/sample - loss: 1.4531 - accuracy: 0.4686 - val_loss: 1.5439 - val_accuracy: 0.4339
# Epoch 5/30
# 5000/5000 [==============================] - 1s 213us/sample - loss: 0.0503 - accuracy: 0.9868 - val_loss: 3.1355 - val_accuracy: 0.5260
# Epoch 25/30
# 5000/5000 [==============================] - 1s 207us/sample - loss: 0.0267 - accuracy: 0.9950 - val_loss: 3.5156 - val_accuracy: 0.5035
# Epoch 26/30
# 5000/5000 [==============================] - 1s 206us/sample - loss: 0.1315 - accuracy: 0.9552 - val_loss: 3.1928 - val_accuracy: 0.5049
# Epoch 27/30
# 5000/5000 [==============================] - 1s 222us/sample - loss: 0.0495 - accuracy: 0.9860 - val_loss: 3.3016 - val_accuracy: 0.5246
# Epoch 28/30
# 5000/5000 [==============================] - 1s 204us/sample - loss: 0.1124 - accuracy: 0.9644 - val_loss: 2.9626 - val_accuracy: 0.5224
# Epoch 29/30
# 5000/5000 [==============================] - 1s 208us/sample - loss: 0.0898 - accuracy: 0.9710 - val_loss: 3.2785 - val_accuracy: 0.5146
# Epoch 30/30
# 5000/5000 [==============================] - 1s 206us/sample - loss: 0.0294 - accuracy: 0.9928 - val_loss: 3.5625 - val_accuracy: 0.5223

# %%
# plot the development of the accuracy and loss during training
plt.figure(figsize=(12,4))
plt.subplot(1,2,(1))
plt.plot(history.history['accuracy'],linestyle='-.')
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='lower right')
plt.subplot(1,2,(2))
plt.plot(history.history['loss'],linestyle='-.')
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper right')

# %% [markdown]
# #### Prediction on the test set after training on original data
#
# Now, let's use CNN that was trained on the original data to predict new unseen data (our testdata). We determine the confusion matrix and the accuracy on the testdata to evaluate the classification performance.

# %%
pred=model.predict(X_test)
print(confusion_matrix(np.argmax(Y_test,axis=1),np.argmax(pred,axis=1)))
acc = np.sum(np.argmax(Y_test,axis=1)==np.argmax(pred,axis=1))/len(pred)
print("Acc_cnn= " , acc)
# Out:
# [[486  47  83  27  38  13  29  18 202  57]
#  [ 36 697  14  17  13   5  27  13  61 117]
#  [ 60  23 408  76 103  73 153  48  33  23]
#  [ 12  23  79 323  83 136 222  56  25  41]
#  [ 31  12 112  83 413  33 191  96  15  14]
#  [ 12  16  97 230  60 327 134  84  15  25]
#  [  2  19  49  64  46  20 757  19  11  13]
#  [ 17  15  44  81  88  72  51 578  14  40]
#  [ 82  80  18  31  12   7  20   9 700  41]
#  [ 39 179  17  38   7  12  42  34  73 559]]
# Acc_cnn=  0.5248

# %%
# define CNN with 2 convolution blocks and 2 fully connected layers
model = Sequential()

model.add(Convolution2D(8,kernel_size,padding='same',input_shape=input_shape))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Convolution2D(8, kernel_size,padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=pool_size))

model.add(Convolution2D(16, kernel_size,padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Convolution2D(16,kernel_size,padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=pool_size))


model.add(Flatten())
model.add(Dense(300))
#model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.3))
model.add(Dense(100))
#model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.3))
model.add(Dense(nb_classes))
model.add(Activation('softmax'))

# compile model and intitialize weights
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
# summarize model along with number of model weights
model.summary()
# Out:
# Model: "sequential_25"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_97 (Conv2D)           (None, 32, 32, 8)         224
# _________________________________________________________________
# activation_157 (Activation)  (None, 32, 32, 8)         0
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 32, 32, 8)         0
# _________________________________________________________________
# conv2d_98 (Conv2D)           (None, 32, 32, 8)         584
# _________________________________________________________________
# activation_158 (Activation)  (None, 32, 32, 8)         0
# _________________________________________________________________
# max_pooling2d_48 (MaxPooling (None, 16, 16, 8)         0
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 16, 16, 8)         0
# _________________________________________________________________
# conv2d_99 (Conv2D)           (None, 16, 16, 16)        1168
# _________________________________________________________________
# activation_159 (Activation)  (None, 16, 16, 16)        0
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_100 (Conv2D)          (None, 16, 16, 16)        2320
# _________________________________________________________________
# activation_160 (Activation)  (None, 16, 16, 16)        0
# _________________________________________________________________
# max_pooling2d_49 (MaxPooling (None, 8, 8, 16)          0
# _________________________________________________________________
# flatten_24 (Flatten)         (None, 1024)              0
# _________________________________________________________________
# dense_61 (Dense)             (None, 300)               307500
# _________________________________________________________________
# activation_161 (Activation)  (None, 300)               0
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 300)               0
# _________________________________________________________________
# dense_62 (Dense)             (None, 100)               30100
# _________________________________________________________________
# activation_162 (Activation)  (None, 100)               0
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_63 (Dense)             (None, 10)                1010
# _________________________________________________________________
# activation_163 (Activation)  (None, 10)                0
# =================================================================
# Total params: 342,906
# Trainable params: 342,906
# Non-trainable params: 0
# _________________________________________________________________

# %%
# train the model
history=model.fit(X_train, Y_train, 
                  batch_size=64, 
                  epochs=30,
                  verbose=1, 
                  validation_data=(X_val, Y_val)
                 )
# Out:
# Train on 5000 samples, validate on 10000 samples
# Epoch 1/30
# 5000/5000 [==============================] - 1s 210us/sample - loss: 1.5359 - accuracy: 0.4448 - val_loss: 1.9698 - val_accuracy: 0.3230
# Epoch 2/30
# 5000/5000 [==============================] - 1s 226us/sample - loss: 1.5102 - accuracy: 0.4492 - val_loss: 2.1540 - val_accuracy: 0.2909
# Epoch 3/30
# 5000/5000 [==============================] - 1s 223us/sample - loss: 1.5129 - accuracy: 0.4464 - val_loss: 1.9240 - val_accuracy: 0.3398
# Epoch 4/30
# 5000/5000 [==============================] - 1s 220us/sample - loss: 1.4940 - accuracy: 0.4536 - val_loss: 1.8616 - val_accuracy: 0.3521
# Epoch 5/30
# 5000/5000 [==============================] - 1s 229us/sample - loss: 1.5162 - accuracy: 0.4520 - val_loss: 1.9148 - val_accuracy: 0.3390
# Epoch 6/30
# 5000/5000 [==============================] - 1s 219us/sample - loss: 1.4677 - accuracy: 0.4680 - val_loss: 1.7278 - val_accuracy: 0.3781
# Epoch 7/30
# 5000/5000 [==============================] - 1s 230us/sample - loss: 1.4737 - accuracy: 0.4770 - val_loss: 1.6691 - val_accuracy: 0.3993
# Epoch 8/30
# 5000/5000 [==============================] - 1s 221us/sample - loss: 1.4454 - accuracy: 0.4738 - val_loss: 1.7739 - val_accuracy: 0.3815
# Epoch 9/30
# 5000/5000 [==============================] - 1s 210us/sample - loss: 1.4514 - accuracy: 0.4716 - val_loss: 1.7635 - val_accuracy: 0.3846
# Epoch 10/30
# 5000/5000 [==============================] - 1s 227us/sample - loss: 1.4408 - accuracy: 0.4810 - val_loss: 1.8088 - val_accuracy: 0.3666
# Epoch 11/30
# 5000/5000 [==============================] - 1s 215us/sample - loss: 1.4260 - accuracy: 0.4806 - val_loss: 1.8561 - val_accuracy: 0.3560
# Epoch 12/30
# 5000/5000 [==============================] - 1s 229us/sample - loss: 1.4317 - accuracy: 0.4846 - val_loss: 1.7666 - val_accuracy: 0.3800
# Epoch 13/30
# 5000/5000 [==============================] - 1s 214us/sample - loss: 1.4231 - accuracy: 0.4842 - val_loss: 1.8689 - val_accuracy: 0.3543
# Epoch 14/30
# 5000/5000 [==============================] - 1s 219us/sample - loss: 1.4112 - accuracy: 0.4822 - val_loss: 1.9828 - val_accuracy: 0.3335
# Epoch 15/30
# 5000/5000 [==============================] - 1s 213us/sample - loss: 1.3954 - accuracy: 0.4958 - val_loss: 1.8746 - val_accuracy: 0.3586
# Epoch 16/30
# 5000/5000 [==============================] - 1s 218us/sample - loss: 1.3883 - accuracy: 0.4960 - val_loss: 1.7109 - val_accuracy: 0.3964
# Epoch 17/30
# 5000/5000 [==============================] - 1s 213us/sample - loss: 1.3956 - accuracy: 0.5028 - val_loss: 1.7522 - val_accuracy: 0.3915
# Epoch 18/30
# 5000/5000 [==============================] - 1s 225us/sample - loss: 1.3746 - accuracy: 0.5016 - val_loss: 1.8177 - val_accuracy: 0.3717
# Epoch 19/30
# 5000/5000 [==============================] - 1s 225us/sample - loss: 1.3489 - accuracy: 0.5154 - val_loss: 1.8166 - val_accuracy: 0.3741
# Epoch 20/30
# 5000/5000 [==============================] - 1s 210us/sample - loss: 1.3629 - accuracy: 0.5094 - val_loss: 1.7309 - val_accuracy: 0.3856
# Epoch 21/30
# 5000/5000 [==============================] - 1s 223us/sample - loss: 1.3497 - accuracy: 0.5170 - val_loss: 1.7933 - val_accuracy: 0.3839
# Epoch 22/30
# 5000/5000 [==============================] - 1s 241us/sample - loss: 1.3560 - accuracy: 0.5238 - val_loss: 1.7679 - val_accuracy: 0.3887
# Epoch 23/30
# 5000/5000 [==============================] - 1s 229us/sample - loss: 1.3404 - accuracy: 0.5128 - val_loss: 1.7980 - val_accuracy: 0.3805
# Epoch 24/30
# 5000/5000 [==============================] - 1s 210us/sample - loss: 1.3176 - accuracy: 0.5188 - val_loss: 1.9087 - val_accuracy: 0.3722
# Epoch 25/30
# 5000/5000 [==============================] - 1s 221us/sample - loss: 1.3181 - accuracy: 0.5292 - val_loss: 1.7434 - val_accuracy: 0.3964
# Epoch 26/30
# 5000/5000 [==============================] - 1s 228us/sample - loss: 1.3288 - accuracy: 0.5184 - val_loss: 1.8875 - val_accuracy: 0.3596
# Epoch 27/30
# 5000/5000 [==============================] - 1s 217us/sample - loss: 1.2958 - accuracy: 0.5338 - val_loss: 2.0415 - val_accuracy: 0.3403
# Epoch 28/30
# 5000/5000 [==============================] - 1s 218us/sample - loss: 1.3141 - accuracy: 0.5234 - val_loss: 1.8226 - val_accuracy: 0.3857
# Epoch 29/30
# 5000/5000 [==============================] - 1s 212us/sample - loss: 1.2916 - accuracy: 0.5364 - val_loss: 1.9117 - val_accuracy: 0.3630
# Epoch 30/30
# 5000/5000 [==============================] - 1s 217us/sample - loss: 1.2603 - accuracy: 0.5466 - val_loss: 1.6771 - val_accuracy: 0.4108

# %%
# plot the development of the accuracy and loss during training
plt.figure(figsize=(12,4))
plt.subplot(1,2,(1))
plt.plot(history.history['accuracy'],linestyle='-.')
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='lower right')
plt.subplot(1,2,(2))
plt.plot(history.history['loss'],linestyle='-.')
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper right')

# %% [markdown]
# #### Prediction on the test set after training on original data
#
# Now, let's use CNN that was trained on the original data to predict new unseen data (our testdata). We determine the confusion matrix and the accuracy on the testdata to evaluate the classification performance.

# %%
pred=model.predict(X_test)
print(confusion_matrix(np.argmax(Y_test,axis=1),np.argmax(pred,axis=1)))
acc = np.sum(np.argmax(Y_test,axis=1)==np.argmax(pred,axis=1))/len(pred)
print("Acc_cnn= " , acc)
# Out:
# [[549  33  62  39  22  18  13  20 181  63]
#  [ 48 672  10  22   3  18  10  12  45 160]
#  [ 70  15 360 112 121 148  79  59  25  11]
#  [ 24  28  83 388  63 231 101  50  12  20]
#  [ 36  15 146  84 426  83  81 106  13  10]
#  [ 16   9  93 203  49 481  46  77  10  16]
#  [  9   6  60 135  93  57 586  32   3  19]
#  [ 27  10  25  60  75 133  31 600   8  31]
#  [ 98  52  28  51   7  19   3  10 689  43]
#  [ 51 166  11  45   2  20  16  47  45 597]]
# Acc_cnn=  0.5348

# %% [markdown]
# #### Exercise
#
# Compre the performances of the fcNN on the MNIST dataset to the CNN performances.
# What do you observe?
# Compre the performance of the CNN on the original and on the shuffled dataset.
# Try to explain the differences.
